# %%
import json
import math
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import re
import torch
from datasets import Dataset
from itertools import chain
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split
from transformers import (
    BertForSequenceClassification,
    BertTokenizer,
    LEDForConditionalGeneration,
    LEDTokenizer,
    Seq2SeqTrainingArguments,
    Trainer
)

# %%
# !nvidia-smi
# Out:
# Sun Oct  6 17:55:47 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 555.42.06              Driver Version: 555.42.06      CUDA Version: 12.5     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A40                     Off |   00000000:01:00.0 Off |                    0 |
# |  0%   61C    P0            211W /  300W |   17464MiB /  46068MiB |    100%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  NVIDIA A40                     Off |   00000000:42:00.0 Off |                    0 |
# |  0%   52C    P0            215W /  300W |   28087MiB /  46068MiB |    100%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   2  NVIDIA A40                     Off |   00000000:81:00.0 Off |                    0 |
# |  0%   56C    P0            234W /  300W |   29216MiB /  46068MiB |    100%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   3  NVIDIA A40                     Off |   00000000:C1:00.0 Off |                    0 |
# |  0%   72C    P0            257W /  300W |   18157MiB /  46068MiB |    100%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A   3289672      C   python                                       8446MiB |
# |    0   N/A  N/A   3314958      C   python                                       9004MiB |
# |    1   N/A  N/A   3334466      C   python3                                     28078MiB |
# |    2   N/A  N/A   3321160      C   python3                                     28938MiB |
# |    2   N/A  N/A   3338062      C   ...tah/anaconda3/envs/myenv/bin/python        264MiB |
# |    3   N/A  N/A   3095424      C   python                                        882MiB |
# |    3   N/A  N/A   3292939      C   python                                       8266MiB |
# |    3   N/A  N/A   3318545      C   python                                       8990MiB |
# +-----------------------------------------------------------------------------------------+

# %%
device = torch.device("cpu")
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
# Check if CUDA is available
if torch.cuda.is_available():
    # Get the number of GPUs available
    num_gpus = torch.cuda.device_count()
    
    if num_gpus >= 3:  # Check if there are at least 3 GPUs
        # Set the device to GPU 2
        device = torch.device("cuda:2")
        print(f"Set device to: {device}")
        print(f"GPU Name: {torch.cuda.get_device_name(2)}")
        
        # Set GPU 2 as the default device
        torch.cuda.set_device(2)
        
        # Verify the current device
        current_device = torch.cuda.current_device()
        print(f"Current process is using GPU ID: {current_device}, GPU Name: {torch.cuda.get_device_name(current_device)}")
        
        # Test tensor creation
        test_tensor = torch.randn(10, 10, device=device)
        print(f"Test tensor is on device: {test_tensor.device}")
        
        # Example model placement
        class SimpleModel(torch.nn.Module):
            def __init__(self):
                super().__init__()
                self.linear = torch.nn.Linear(10, 10)
            
            def forward(self, x):
                return self.linear(x)
        
        model = SimpleModel()
        model.to(device)
        print(f"Model is on device: {next(model.parameters()).device}")
    
    else:
        print("Device 2 is not available. Using Device 0.")
        device = torch.device("cuda:0")
else:
    print("CUDA is not available. Using CPU.")
    device = torch.device("cpu")

print(f"Final check: Current process is using GPU ID: {torch.cuda.current_device()}, GPU Name: {torch.cuda.get_device_name(torch.cuda.current_device())}")
# Out:
# Set device to: cuda:2
# GPU Name: NVIDIA A40
# Current process is using GPU ID: 2, GPU Name: NVIDIA A40
# Test tensor is on device: cuda:2
# Model is on device: cuda:2
# Final check: Current process is using GPU ID: 2, GPU Name: NVIDIA A40

# %%
from datasets import load_dataset

def load_datasets(dataset1_name, dataset2_name):

    dataset1 = load_dataset(dataset1_name)
    dataset2 = load_dataset(dataset2_name)
    return dataset1, dataset2

def get_unique_urls(dataset1, dataset2):
    """
    Get URLs that are in dataset1 but not in dataset2.
    
    Parameters:
    - dataset1: The first dataset.
    - dataset2: The second dataset.
    
    Returns:
    A list of URLs that are in dataset1 but not in dataset2.
    """
    urls1 = set(dataset1['train']['url'])
    urls2 = set(dataset2['train']['url'])
    
    unique_urls = urls1 - urls2
    return list(unique_urls)

# Example usage
dataset1_name = 'ahmed275/FILTERED_FAST_1'
dataset2_name = 'ahmed275/FILTERED_SLOW'

# Load the datasets
dataset1, dataset2 = load_datasets(dataset1_name, dataset2_name)

# Get the unique URLs
unique_urls = get_unique_urls(dataset1, dataset2)

# Print the unique URLs
print("URLs in dataset1 but not in dataset2:")
for url in unique_urls:
    print(url)
# Out:
# URLs in dataset1 but not in dataset2:
# https://www.oyez.org/cases/1993/93-644
# https://www.oyez.org/cases/1997/97-428
# https://www.oyez.org/cases/1996/95-1340
# https://www.oyez.org/cases/1985/84-1362
# https://www.oyez.org/cases/1962/490
# https://www.oyez.org/cases/1994/93-7901
# https://www.oyez.org/cases/1995/95-5257
# https://www.oyez.org/cases/2001/00-1770
# https://www.oyez.org/cases/1996/94-1988
# https://www.oyez.org/cases/1992/91-946
# https://www.oyez.org/cases/1992/91-1353
# https://www.oyez.org/cases/1993/92-2058
# https://www.oyez.org/cases/2002/01-705
# https://www.oyez.org/cases/1992/91-522
# https://www.oyez.org/cases/1991/91-471
# https://www.oyez.org/cases/1994/93-1631
# https://www.oyez.org/cases/1997/97-643
# https://www.oyez.org/cases/1999/99-51
# https://www.oyez.org/cases/1999/99-137
# https://www.oyez.org/cases/1991/90-1361
# https://www.oyez.org/cases/1994/94-167
# https://www.oyez.org/cases/1996/96-552
# https://www.oyez.org/cases/1996/96-511
# https://www.oyez.org/cases/1991/90-6704
# https://www.oyez.org/cases/2001/00-1072
# https://www.oyez.org/cases/1991/90-1424
# https://www.oyez.org/cases/1995/94-1140
# https://www.oyez.org/cases/1993/92-1639
# https://www.oyez.org/cases/2000/00-189
# https://www.oyez.org/cases/1995/94-203
# https://www.oyez.org/cases/1994/93-1286
# https://www.oyez.org/cases/1992/91-871
# https://www.oyez.org/cases/1993/92-854
# https://www.oyez.org/cases/2002/01-1067
# https://www.oyez.org/cases/2000/99-1977
# https://www.oyez.org/cases/1993/92-1479
# https://www.oyez.org/cases/1991/91-542
# https://www.oyez.org/cases/1997/96-1482
# https://www.oyez.org/cases/1999/99-474
# https://www.oyez.org/cases/2001/00-927
# https://www.oyez.org/cases/1997/96-1581
# https://www.oyez.org/cases/1992/91-1158
# https://www.oyez.org/cases/1994/93-1128
# https://www.oyez.org/cases/1991/90-985
# https://www.oyez.org/cases/1991/91-763
# https://www.oyez.org/cases/1999/98-8384
# https://www.oyez.org/cases/1997/96-1654
# https://www.oyez.org/cases/2002/01-1368
# https://www.oyez.org/cases/2002/01-757
# https://www.oyez.org/cases/1991/90-1846
# https://www.oyez.org/cases/1997/96-827
# https://www.oyez.org/cases/1997/97-115
# https://www.oyez.org/cases/1996/96-243
# https://www.oyez.org/cases/2000/00-6677
# https://www.oyez.org/cases/1993/93-141
# https://www.oyez.org/cases/1992/91-7849
# https://www.oyez.org/cases/1992/91-1160
# https://www.oyez.org/cases/2001/01-147
# https://www.oyez.org/cases/2000/99-1038
# https://www.oyez.org/cases/2000/00-836
# https://www.oyez.org/cases/1994/93-6892
# https://www.oyez.org/cases/1993/91-1950
# https://www.oyez.org/cases/2001/00-1831
# https://www.oyez.org/cases/2001/00-6029
# https://www.oyez.org/cases/1997/96-738
# https://www.oyez.org/cases/1993/92-1239
# https://www.oyez.org/cases/1992/91-1833
# https://www.oyez.org/cases/1995/94-1340
# https://www.oyez.org/cases/1995/95-323
# https://www.oyez.org/cases/1991/90-6297
# https://www.oyez.org/cases/1991/90-1205
# https://www.oyez.org/cases/2001/00-1249
# https://www.oyez.org/cases/1999/98-1255
# https://www.oyez.org/cases/1992/91-1594
# https://www.oyez.org/cases/1992/91-948
# https://www.oyez.org/cases/1998/97-826
# https://www.oyez.org/cases/1993/91-2012
# https://www.oyez.org/cases/1995/95-340
# https://www.oyez.org/cases/2000/99-859
# https://www.oyez.org/cases/1992/91-7873
# https://www.oyez.org/cases/1996/95-1181
# https://www.oyez.org/cases/1997/96-1470
# https://www.oyez.org/cases/2001/00-853
# https://www.oyez.org/cases/1991/90-970
# https://www.oyez.org/cases/1991/90-584
# https://www.oyez.org/cases/1992/91-1538
# https://www.oyez.org/cases/1999/98-942
# https://www.oyez.org/cases/1996/95-1717
# https://www.oyez.org/cases/2000/99-7504
# https://www.oyez.org/cases/2002/02-428
# https://www.oyez.org/cases/1995/94-1175
# https://www.oyez.org/cases/1994/94-834
# https://www.oyez.org/cases/2000/00-454
# https://www.oyez.org/cases/1992/91-1393
# https://www.oyez.org/cases/2001/01-682
# https://www.oyez.org/cases/1994/93-1170
# https://www.oyez.org/cases/1996/96-542
# https://www.oyez.org/cases/1996/95-992
# https://www.oyez.org/cases/1996/96-126
# https://www.oyez.org/cases/1995/94-1809
# https://www.oyez.org/cases/1996/96-110
# https://www.oyez.org/cases/1992/91-2045
# https://www.oyez.org/cases/1996/96-262
# https://www.oyez.org/cases/1996/95-1872
# https://www.oyez.org/cases/1991/90-954
# https://www.oyez.org/cases/1993/93-489
# https://www.oyez.org/cases/1997/97-6146
# https://www.oyez.org/cases/1992/91-781
# https://www.oyez.org/cases/1994/94-286
# https://www.oyez.org/cases/1996/96-318
# https://www.oyez.org/cases/2002/01-1418
# https://www.oyez.org/cases/2001/01-309
# https://www.oyez.org/cases/2002/02-371
# https://www.oyez.org/cases/1998/97-930
# https://www.oyez.org/cases/1997/96-8516
# https://www.oyez.org/cases/1995/95-5207
# https://www.oyez.org/cases/2001/00-507
# https://www.oyez.org/cases/2001/00-795
# https://www.oyez.org/cases/1992/91-2003
# https://www.oyez.org/cases/1991/90-1279
# https://www.oyez.org/cases/1992/92-515
# https://www.oyez.org/cases/1993/92-1812
# https://www.oyez.org/cases/1996/96-6133
# https://www.oyez.org/cases/2000/99-1185
# https://www.oyez.org/cases/1996/96-270
# https://www.oyez.org/cases/1996/95-1764
# https://www.oyez.org/cases/1996/95-1858
# https://www.oyez.org/cases/1991/90-1859
# https://www.oyez.org/cases/1999/98-1441
# https://www.oyez.org/cases/2002/02-679
# https://www.oyez.org/cases/2000/99-1178
# https://www.oyez.org/cases/1992/91-1326
# https://www.oyez.org/cases/1994/94-455
# https://www.oyez.org/cases/1998/97-1909
# https://www.oyez.org/cases/1993/92-1074
# https://www.oyez.org/cases/1991/89-1290
# https://www.oyez.org/cases/1997/97-42
# https://www.oyez.org/cases/1992/91-7604
# https://www.oyez.org/cases/2001/00-957
# https://www.oyez.org/cases/1992/91-1657
# https://www.oyez.org/cases/1997/97-174
# https://www.oyez.org/cases/1995/94-8729
# https://www.oyez.org/cases/2002/01-1229
# https://www.oyez.org/cases/1999/98-9349
# https://www.oyez.org/cases/1994/93-1883
# https://www.oyez.org/cases/1998/98-5864
# https://www.oyez.org/cases/1998/98-231
# https://www.oyez.org/cases/1976/75-554
# https://www.oyez.org/cases/2001/00-952
# https://www.oyez.org/cases/1992/92-5653
# https://www.oyez.org/cases/1992/92-357
# https://www.oyez.org/cases/1997/96-643
# https://www.oyez.org/cases/1997/96-910
# https://www.oyez.org/cases/1994/94-560
# https://www.oyez.org/cases/1998/98-536
# https://www.oyez.org/cases/1998/97-1252
# https://www.oyez.org/cases/1998/98-470
# https://www.oyez.org/cases/1999/99-5525
# https://www.oyez.org/cases/1991/90-727
# https://www.oyez.org/cases/1992/91-1618
# https://www.oyez.org/cases/1991/91-535
# https://www.oyez.org/cases/1994/94-270
# https://www.oyez.org/cases/1992/91-886
# https://www.oyez.org/cases/1994/93-1318
# https://www.oyez.org/cases/1957/90
# https://www.oyez.org/cases/1998/97-2045
# https://www.oyez.org/cases/1997/96-1291
# https://www.oyez.org/cases/1998/98-387
# https://www.oyez.org/cases/1996/95-1100
# https://www.oyez.org/cases/1993/92-74
# https://www.oyez.org/cases/1994/93-7927
# https://www.oyez.org/cases/2001/00-1073
# https://www.oyez.org/cases/1998/98-262
# https://www.oyez.org/cases/1993/92-8841
# https://www.oyez.org/cases/2000/99-2036
# https://www.oyez.org/cases/1992/91-990
# https://www.oyez.org/cases/1989/88-1897
# https://www.oyez.org/cases/1999/99-579
# https://www.oyez.org/cases/2001/01-714
# https://www.oyez.org/cases/2000/99-1908
# https://www.oyez.org/cases/1998/97-1709
# https://www.oyez.org/cases/1991/91-17
# https://www.oyez.org/cases/1997/97-282
# https://www.oyez.org/cases/1991/91-594
# https://www.oyez.org/cases/1999/98-1811
# https://www.oyez.org/cases/1996/95-1478
# https://www.oyez.org/cases/1995/94-6615
# https://www.oyez.org/cases/1998/98-369
# https://www.oyez.org/cases/1993/92-1546
# https://www.oyez.org/cases/1999/98-1856
# https://www.oyez.org/cases/1993/92-1625
# https://www.oyez.org/cases/1996/95-974
# https://www.oyez.org/cases/1997/96-1584
# https://www.oyez.org/cases/1992/91-8674
# https://www.oyez.org/cases/1994/93-1841
# https://www.oyez.org/cases/1995/95-8836
# https://www.oyez.org/cases/2002/01-6978
# https://www.oyez.org/cases/1992/92-102
# https://www.oyez.org/cases/1995/94-818
# https://www.oyez.org/cases/1992/91-7749
# https://www.oyez.org/cases/1992/92-6073
# https://www.oyez.org/cases/1997/96-1866
# https://www.oyez.org/cases/1998/97-1992
# https://www.oyez.org/cases/2002/01-1806
# https://www.oyez.org/cases/1998/97-1642
# https://www.oyez.org/cases/1993/93-405
# https://www.oyez.org/cases/2002/02-634
# https://www.oyez.org/cases/1994/93-908
# https://www.oyez.org/cases/1997/97-689
# https://www.oyez.org/cases/2002/01-1572
# https://www.oyez.org/cases/1997/97-16
# https://www.oyez.org/cases/2000/00-24
# https://www.oyez.org/cases/1997/97-873
# https://www.oyez.org/cases/1997/96-8732
# https://www.oyez.org/cases/2002/01-704
# https://www.oyez.org/cases/1997/96-1487
# https://www.oyez.org/cases/1997/97-679
# https://www.oyez.org/cases/1999/99-699
# https://www.oyez.org/cases/1993/93-744
# https://www.oyez.org/cases/1994/93-1612
# https://www.oyez.org/cases/1997/96-1577
# https://www.oyez.org/cases/2001/00-1214
# https://www.oyez.org/cases/1996/96-6867
# https://www.oyez.org/cases/1994/94-251
# https://www.oyez.org/cases/1992/92-641
# https://www.oyez.org/cases/1994/94-500
# https://www.oyez.org/cases/1996/95-1621
# https://www.oyez.org/cases/1996/95-1065
# https://www.oyez.org/cases/1998/97-8629
# https://www.oyez.org/cases/2000/00-767
# https://www.oyez.org/cases/1998/97-2000
# https://www.oyez.org/cases/1999/98-6322
# https://www.oyez.org/cases/2000/99-2035
# https://www.oyez.org/cases/1971/70-27
# https://www.oyez.org/cases/1994/93-1823
# https://www.oyez.org/cases/1995/95-5841
# https://www.oyez.org/cases/1995/95-354
# https://www.oyez.org/cases/1994/93-823
# https://www.oyez.org/cases/1999/99-150
# https://www.oyez.org/cases/1997/96-1400
# https://www.oyez.org/cases/1993/93-5209
# https://www.oyez.org/cases/2000/99-8576
# https://www.oyez.org/cases/1995/95-26
# https://www.oyez.org/cases/1995/95-244
# https://www.oyez.org/cases/1999/98-1993
# https://www.oyez.org/cases/1992/91-1721
# https://www.oyez.org/cases/1999/99-536
# https://www.oyez.org/cases/1991/90-6105
# https://www.oyez.org/cases/1999/98-963
# https://www.oyez.org/cases/1997/96-957
# https://www.oyez.org/cases/2001/00-1250
# https://www.oyez.org/cases/1992/92-1
# https://www.oyez.org/cases/1996/95-928
# https://www.oyez.org/cases/1996/95-1694
# https://www.oyez.org/cases/1996/95-897
# https://www.oyez.org/cases/1998/97-1130
# https://www.oyez.org/cases/1987/86-656
# https://www.oyez.org/cases/1999/98-822
# https://www.oyez.org/cases/1994/94-790
# https://www.oyez.org/cases/1991/91-779
# https://www.oyez.org/cases/1999/98-818
# https://www.oyez.org/cases/1995/94-1244
# https://www.oyez.org/cases/1995/94-1511
# https://www.oyez.org/cases/1988/87-998
# https://www.oyez.org/cases/1996/95-1081
# https://www.oyez.org/cases/1995/94-1664
# https://www.oyez.org/cases/1999/99-244
# https://www.oyez.org/cases/1992/91-767
# https://www.oyez.org/cases/2000/99-1687
# https://www.oyez.org/cases/1999/99-312
# https://www.oyez.org/cases/1999/98-1167
# https://www.oyez.org/cases/1995/94-947
# https://www.oyez.org/cases/1997/96-976
# https://www.oyez.org/cases/1998/97-1184
# https://www.oyez.org/cases/1993/93-6497
# https://www.oyez.org/cases/1992/92-34
# https://www.oyez.org/cases/1996/96-203
# https://www.oyez.org/cases/1995/95-129
# https://www.oyez.org/cases/1991/90-1341
# https://www.oyez.org/cases/2002/01-1500
# https://www.oyez.org/cases/1995/94-1361
# https://www.oyez.org/cases/2002/01-729
# https://www.oyez.org/cases/1994/94-623
# https://www.oyez.org/cases/2002/02-306
# https://www.oyez.org/cases/1992/92-486
# https://www.oyez.org/cases/2000/99-9073
# https://www.oyez.org/cases/1995/95-5661
# https://www.oyez.org/cases/2001/00-758
# https://www.oyez.org/cases/2002/01-618
# https://www.oyez.org/cases/2000/99-1235
# https://www.oyez.org/cases/2000/98-1768
# https://www.oyez.org/cases/2002/01-800
# https://www.oyez.org/cases/2002/02-5664
# https://www.oyez.org/cases/2002/01-10873
# https://www.oyez.org/cases/2001/01-518
# https://www.oyez.org/cases/1997/96-871
# https://www.oyez.org/cases/1991/91-571
# https://www.oyez.org/cases/1999/99-5716
# https://www.oyez.org/cases/1999/99-5
# https://www.oyez.org/cases/2002/02-695
# https://www.oyez.org/cases/1992/92-166
# https://www.oyez.org/cases/1998/98-405
# https://www.oyez.org/cases/1961/396
# https://www.oyez.org/cases/1994/94-780
# https://www.oyez.org/cases/1999/98-9537
# https://www.oyez.org/cases/1991/91-744
# https://www.oyez.org/cases/1994/94-5707
# https://www.oyez.org/cases/1991/90-925
# https://www.oyez.org/cases/2000/99-1978
# https://www.oyez.org/cases/1991/91-611
# https://www.oyez.org/cases/1991/90-1577
# https://www.oyez.org/cases/1993/92-8579
# https://www.oyez.org/cases/1991/90-1278
# https://www.oyez.org/cases/1999/98-1299
# https://www.oyez.org/cases/1991/90-1918
# https://www.oyez.org/cases/1993/93-5131
# https://www.oyez.org/cases/2001/01-521
# https://www.oyez.org/cases/1991/90-967
# https://www.oyez.org/cases/1991/90-681
# https://www.oyez.org/cases/1993/92-1662
# https://www.oyez.org/cases/1997/96-1971
# https://www.oyez.org/cases/1992/92-114
# https://www.oyez.org/cases/1998/98-97
# https://www.oyez.org/cases/1991/91-615
# https://www.oyez.org/cases/2002/01-1289
# https://www.oyez.org/cases/1991/90-1488
# https://www.oyez.org/cases/1996/95-1232
# https://www.oyez.org/cases/2002/01-1231
# https://www.oyez.org/cases/1998/97-843
# https://www.oyez.org/cases/1995/95-232
# https://www.oyez.org/cases/1996/96-663
# https://www.oyez.org/cases/1991/90-1596
# https://www.oyez.org/cases/1993/92-780
# https://www.oyez.org/cases/1992/91-8199
# https://www.oyez.org/cases/1998/97-7541
# https://www.oyez.org/cases/1999/99-5746
# https://www.oyez.org/cases/2000/99-1571
# https://www.oyez.org/cases/2001/01-298
# https://www.oyez.org/cases/1995/94-1453
# https://www.oyez.org/cases/1997/96-792
# https://www.oyez.org/cases/1998/97-1147
# https://www.oyez.org/cases/1997/96-8653
# https://www.oyez.org/cases/1997/96-1037
# https://www.oyez.org/cases/2001/01-394
# https://www.oyez.org/cases/1998/97-1802
# https://www.oyez.org/cases/1993/92-741
# https://www.oyez.org/cases/1993/93-120
# https://www.oyez.org/cases/1994/94-395
# https://www.oyez.org/cases/1996/96-5658
# https://www.oyez.org/cases/1996/96-842
# https://www.oyez.org/cases/2001/00-1531
# https://www.oyez.org/cases/1993/91-1523
# https://www.oyez.org/cases/1996/96-79
# https://www.oyez.org/cases/1991/90-889
# https://www.oyez.org/cases/1997/96-7171
# https://www.oyez.org/cases/1998/97-1472
# https://www.oyez.org/cases/1994/93-1677
# https://www.oyez.org/cases/1996/96-5955
# https://www.oyez.org/cases/1994/93-1911
# https://www.oyez.org/cases/2001/00-10666
# https://www.oyez.org/cases/1991/91-538
# https://www.oyez.org/cases/2002/01-270
# https://www.oyez.org/cases/1997/96-6839
# https://www.oyez.org/cases/1991/90-741
# https://www.oyez.org/cases/1999/99-658
# https://www.oyez.org/cases/1994/94-558
# https://www.oyez.org/cases/1996/95-1441
# https://www.oyez.org/cases/1991/90-1912
# https://www.oyez.org/cases/1991/90-1029
# https://www.oyez.org/cases/2001/00-1021
# https://www.oyez.org/cases/1991/91-810
# https://www.oyez.org/cases/2000/99-804
# https://www.oyez.org/cases/1994/94-859
# https://www.oyez.org/cases/2000/00-1011
# https://www.oyez.org/cases/1995/95-157
# https://www.oyez.org/cases/2002/02-69
# https://www.oyez.org/cases/1994/94-788
# https://www.oyez.org/cases/1991/90-1791
# https://www.oyez.org/cases/1995/95-266
# https://www.oyez.org/cases/1998/98-6
# https://www.oyez.org/cases/1997/96-8986
# https://www.oyez.org/cases/1993/92-1450
# https://www.oyez.org/cases/1999/99-401
# https://www.oyez.org/cases/1999/99-116
# https://www.oyez.org/cases/1991/91-159
# https://www.oyez.org/cases/1998/98-131
# https://www.oyez.org/cases/2002/01-1015
# https://www.oyez.org/cases/1999/99-161
# https://www.oyez.org/cases/1992/91-1043
# https://www.oyez.org/cases/1979/79-5601
# https://www.oyez.org/cases/1995/95-865
# https://www.oyez.org/cases/1994/93-1197
# https://www.oyez.org/cases/1993/92-1223
# https://www.oyez.org/cases/1996/95-1853
# https://www.oyez.org/cases/1994/93-1456
# https://www.oyez.org/cases/2001/01-417
# https://www.oyez.org/cases/1999/98-1288
# https://www.oyez.org/cases/1999/99-7000
# https://www.oyez.org/cases/2001/99-1996
# https://www.oyez.org/cases/1998/97-2048
# https://www.oyez.org/cases/1995/95-566
# https://www.oyez.org/cases/1994/94-562
# https://www.oyez.org/cases/1997/96-1579
# https://www.oyez.org/cases/1999/98-1828
# https://www.oyez.org/cases/2002/01-1491
# https://www.oyez.org/cases/2001/99-1823
# https://www.oyez.org/cases/1998/98-184
# https://www.oyez.org/cases/1995/95-489
# https://www.oyez.org/cases/1998/97-1287
# https://www.oyez.org/cases/1991/90-1056
# https://www.oyez.org/cases/2000/99-1551
# https://www.oyez.org/cases/1997/96-1395
# https://www.oyez.org/cases/1995/95-559
# https://www.oyez.org/cases/1972/71-1476
# https://www.oyez.org/cases/1991/91-712
# https://www.oyez.org/cases/1995/95-860
# https://www.oyez.org/cases/1996/96-1671
# https://www.oyez.org/cases/2001/00-9280
# https://www.oyez.org/cases/2000/99-1238
# https://www.oyez.org/cases/1997/96-1613
# https://www.oyez.org/cases/2000/99-1964
# https://www.oyez.org/cases/2001/01-455
# https://www.oyez.org/cases/2000/99-2071
# https://www.oyez.org/cases/2002/02-102
# https://www.oyez.org/cases/1992/91-1231
# https://www.oyez.org/cases/1992/91-1030
# https://www.oyez.org/cases/1997/97-731
# https://www.oyez.org/cases/1993/93-639
# https://www.oyez.org/cases/1995/94-1387
# https://www.oyez.org/cases/1997/96-1279
# https://www.oyez.org/cases/1995/94-1941
# https://www.oyez.org/cases/1991/90-1390
# https://www.oyez.org/cases/1991/90-838
# https://www.oyez.org/cases/1992/92-344
# https://www.oyez.org/cases/1992/92-479
# https://www.oyez.org/cases/1997/96-843
# https://www.oyez.org/cases/1992/91-7580
# https://www.oyez.org/cases/1991/90-6531
# https://www.oyez.org/cases/2000/00-492
# https://www.oyez.org/cases/1996/95-1228
# https://www.oyez.org/cases/2002/01-1862
# https://www.oyez.org/cases/1995/95-386
# https://www.oyez.org/cases/1997/96-8422
# https://www.oyez.org/cases/1997/96-568
# https://www.oyez.org/cases/1998/98-223
# https://www.oyez.org/cases/1991/90-1059
# https://www.oyez.org/cases/1991/90-8370
# https://www.oyez.org/cases/1991/90-1491
# https://www.oyez.org/cases/1995/95-210
# https://www.oyez.org/cases/1992/92-207
# https://www.oyez.org/cases/2002/01-1209
# https://www.oyez.org/cases/2002/01-963
# https://www.oyez.org/cases/2001/01-595
# https://www.oyez.org/cases/1995/95-388
# https://www.oyez.org/cases/1993/92-6921
# https://www.oyez.org/cases/1992/91-2054
# https://www.oyez.org/cases/2002/01-1127
# https://www.oyez.org/cases/2001/00-860
# https://www.oyez.org/cases/1992/91-7328
# https://www.oyez.org/cases/1998/98-5881
# https://www.oyez.org/cases/1994/93-1251
# https://www.oyez.org/cases/1996/95-2074
# https://www.oyez.org/cases/1991/90-1947
# https://www.oyez.org/cases/1999/99-6615
# https://www.oyez.org/cases/1994/93-404
# https://www.oyez.org/cases/2000/99-901
# https://www.oyez.org/cases/1996/95-1873
# https://www.oyez.org/cases/1999/98-1101
# https://www.oyez.org/cases/1994/93-1340
# https://www.oyez.org/cases/1998/98-149
# https://www.oyez.org/cases/1991/90-7477
# https://www.oyez.org/cases/1992/91-1111
# https://www.oyez.org/cases/1991/91-860
# https://www.oyez.org/cases/1993/93-44
# https://www.oyez.org/cases/1992/91-6824
# https://www.oyez.org/cases/1994/94-18
# https://www.oyez.org/cases/1998/97-1985
# https://www.oyez.org/cases/1995/94-1039
# https://www.oyez.org/cases/1992/91-1300
# https://www.oyez.org/cases/1992/91-740
# https://www.oyez.org/cases/1997/97-147
# https://www.oyez.org/cases/1994/93-714
# https://www.oyez.org/cases/2001/00-832
# https://www.oyez.org/cases/1993/93-517
# https://www.oyez.org/cases/1992/91-1010
# https://www.oyez.org/cases/1994/94-6187
# https://www.oyez.org/cases/1997/96-779
# https://www.oyez.org/cases/1991/90-1676
# https://www.oyez.org/cases/1994/93-986
# https://www.oyez.org/cases/1998/97-6203
# https://www.oyez.org/cases/2002/02-469
# https://www.oyez.org/cases/1991/90-1074
# https://www.oyez.org/cases/2002/00-1471
# https://www.oyez.org/cases/1991/91-872
# https://www.oyez.org/cases/1998/97-1536
# https://www.oyez.org/cases/2001/00-1187
# https://www.oyez.org/cases/1999/99-409
# https://www.oyez.org/cases/1996/96-292
# https://www.oyez.org/cases/1995/94-1471
# https://www.oyez.org/cases/2001/00-1937
# https://www.oyez.org/cases/1996/95-789
# https://www.oyez.org/cases/1992/91-2024
# https://www.oyez.org/cases/1993/92-1370
# https://www.oyez.org/cases/1992/91-1695
# https://www.oyez.org/cases/2000/99-1815
# https://www.oyez.org/cases/1996/95-1918
# https://www.oyez.org/cases/2001/01-651
# https://www.oyez.org/cases/1998/97-889
# https://www.oyez.org/cases/1997/96-1462
# https://www.oyez.org/cases/1996/95-938
# https://www.oyez.org/cases/2002/02-215
# https://www.oyez.org/cases/2001/00-1567
# https://www.oyez.org/cases/1996/95-1402
# https://www.oyez.org/cases/1996/96-272
# https://www.oyez.org/cases/1997/97-704
# https://www.oyez.org/cases/1998/97-1008
# https://www.oyez.org/cases/1994/93-723
# https://www.oyez.org/cases/1991/90-6616
# https://www.oyez.org/cases/1999/98-1036
# https://www.oyez.org/cases/1993/92-1856
# https://www.oyez.org/cases/1995/95-6465
# https://www.oyez.org/cases/1994/93-1660
# https://www.oyez.org/cases/1998/97-1139
# https://www.oyez.org/cases/1997/96-1578
# https://www.oyez.org/cases/1996/96-651
# https://www.oyez.org/cases/2002/02-182
# https://www.oyez.org/cases/1960/236
# https://www.oyez.org/cases/1999/98-1464
# https://www.oyez.org/cases/2001/00-1406
# https://www.oyez.org/cases/1998/97-1943
# https://www.oyez.org/cases/1997/97-6270
# https://www.oyez.org/cases/1989/88-1640
# https://www.oyez.org/cases/2001/01-679
# https://www.oyez.org/cases/1978/77-1652
# https://www.oyez.org/cases/1995/94-923
# https://www.oyez.org/cases/2001/00-1853
# https://www.oyez.org/cases/1994/93-7407
# https://www.oyez.org/cases/1994/93-1935
# https://www.oyez.org/cases/1997/97-463
# https://www.oyez.org/cases/1991/91-5843
# https://www.oyez.org/cases/1993/92-1123
# https://www.oyez.org/cases/1993/92-1920
# https://www.oyez.org/cases/1998/97-9217
# https://www.oyez.org/cases/1997/97-5310
# https://www.oyez.org/cases/1998/98-85
# https://www.oyez.org/cases/1996/95-259
# https://www.oyez.org/cases/1996/95-1608
# https://www.oyez.org/cases/1995/95-345
# https://www.oyez.org/cases/1992/92-466
# https://www.oyez.org/cases/1998/97-1230
# https://www.oyez.org/cases/2002/01-7662
# https://www.oyez.org/cases/1997/96-1829
# https://www.oyez.org/cases/1993/92-903
# https://www.oyez.org/cases/1991/90-1599
# https://www.oyez.org/cases/1991/91-543
# https://www.oyez.org/cases/1993/92-1500
# https://www.oyez.org/cases/1991/90-1038
# https://www.oyez.org/cases/1997/97-5737
# https://www.oyez.org/cases/1972/72-549
# https://www.oyez.org/cases/1997/96-1337
# https://www.oyez.org/cases/1992/91-321
# https://www.oyez.org/cases/2001/01-332
# https://www.oyez.org/cases/1999/98-1960
# https://www.oyez.org/cases/1992/91-904
# https://www.oyez.org/cases/1992/91-719
# https://www.oyez.org/cases/2001/00-8452
# https://www.oyez.org/cases/1995/94-805
# https://www.oyez.org/cases/1994/93-1543
# https://www.oyez.org/cases/1992/92-5129
# https://www.oyez.org/cases/1991/90-1090
# https://www.oyez.org/cases/1991/91-164
# https://www.oyez.org/cases/1991/91-367
# https://www.oyez.org/cases/2001/00-511
# https://www.oyez.org/cases/1994/94-172
# https://www.oyez.org/cases/1993/92-1941
# https://www.oyez.org/cases/1996/95-1605
# https://www.oyez.org/cases/2002/01-1420
# https://www.oyez.org/cases/2002/02-281
# https://www.oyez.org/cases/1994/93-762
# https://www.oyez.org/cases/2001/00-1751
# https://www.oyez.org/cases/1996/95-1594
# https://www.oyez.org/cases/1999/98-2043
# https://www.oyez.org/cases/1995/94-9247
# https://www.oyez.org/cases/1999/98-1648
# https://www.oyez.org/cases/2002/01-1118
# https://www.oyez.org/cases/1999/99-478
# https://www.oyez.org/cases/1992/91-1135
# https://www.oyez.org/cases/1992/91-1826
# https://www.oyez.org/cases/1996/95-1184
# https://www.oyez.org/cases/1997/96-795
# https://www.oyez.org/cases/1997/96-670
# https://www.oyez.org/cases/1996/95-1263
# https://www.oyez.org/cases/2001/00-1514
# https://www.oyez.org/cases/1992/92-484
# https://www.oyez.org/cases/1996/95-891
# https://www.oyez.org/cases/2000/99-936
# https://www.oyez.org/cases/2002/01-653
# https://www.oyez.org/cases/1991/90-857
# https://www.oyez.org/cases/1995/94-1530
# https://www.oyez.org/cases/1995/95-809
# https://www.oyez.org/cases/1991/90-1141
# https://www.oyez.org/cases/1992/91-1306
# https://www.oyez.org/cases/1995/95-668
# https://www.oyez.org/cases/1996/95-728
# https://www.oyez.org/cases/1997/97-371
# https://www.oyez.org/cases/1996/95-2031
# https://www.oyez.org/cases/1997/96-1768
# https://www.oyez.org/cases/1993/92-9059
# https://www.oyez.org/cases/2002/01-1120
# https://www.oyez.org/cases/1999/99-5739
# https://www.oyez.org/cases/1992/91-261
# https://www.oyez.org/cases/1994/94-372
# https://www.oyez.org/cases/1999/98-1682
# https://www.oyez.org/cases/1998/97-9361
# https://www.oyez.org/cases/1992/91-1729
# https://www.oyez.org/cases/1992/92-602
# https://www.oyez.org/cases/2001/01-131
# https://www.oyez.org/cases/1993/92-7549
# https://www.oyez.org/cases/1999/98-1109
# https://www.oyez.org/cases/1995/94-8769
# https://www.oyez.org/cases/1998/97-1121
# https://www.oyez.org/cases/1997/97-1192
# https://www.oyez.org/cases/2000/00-157
# https://www.oyez.org/cases/2000/99-1871
# https://www.oyez.org/cases/2000/99-1379
# https://www.oyez.org/cases/2002/01-1757
# https://www.oyez.org/cases/1998/98-238
# https://www.oyez.org/cases/1991/91-913
# https://www.oyez.org/cases/1992/91-610
# https://www.oyez.org/cases/1992/91-1420
# https://www.oyez.org/cases/1991/90-913
# https://www.oyez.org/cases/2000/99-1680
# https://www.oyez.org/cases/1991/91-6382
# https://www.oyez.org/cases/1971/70-18
# https://www.oyez.org/cases/2002/01-1437
# https://www.oyez.org/cases/1995/95-83
# https://www.oyez.org/cases/2001/00-1045
# https://www.oyez.org/cases/1997/97-156
# https://www.oyez.org/cases/2000/99-1884
# https://www.oyez.org/cases/1998/97-7597
# https://www.oyez.org/cases/1992/91-7804
# https://www.oyez.org/cases/2001/00-1089
# https://www.oyez.org/cases/2001/00-1519
# https://www.oyez.org/cases/2000/00-346
# https://www.oyez.org/cases/1991/91-971
# https://www.oyez.org/cases/1993/92-1402
# https://www.oyez.org/cases/2001/00-1260
# https://www.oyez.org/cases/1993/93-670
# https://www.oyez.org/cases/1991/90-408
# https://www.oyez.org/cases/1993/93-397
# https://www.oyez.org/cases/1994/94-688
# https://www.oyez.org/cases/1995/94-967
# https://www.oyez.org/cases/1999/98-7809
# https://www.oyez.org/cases/2000/99-8508
# https://www.oyez.org/cases/1991/90-6113
# https://www.oyez.org/cases/1991/90-1150
# https://www.oyez.org/cases/1999/99-62
# https://www.oyez.org/cases/1995/95-325
# https://www.oyez.org/cases/2000/99-1529
# https://www.oyez.org/cases/1997/96-7901
# https://www.oyez.org/cases/1993/93-376
# https://www.oyez.org/cases/1992/91-5397
# https://www.oyez.org/cases/1999/98-7540
# https://www.oyez.org/cases/1993/92-1911
# https://www.oyez.org/cases/1991/91-1502
# https://www.oyez.org/cases/1992/92-259
# https://www.oyez.org/cases/1991/90-747
# https://www.oyez.org/cases/1994/94-431
# https://www.oyez.org/cases/1993/92-97
# https://www.oyez.org/cases/1992/91-794
# https://www.oyez.org/cases/2000/00-6374
# https://www.oyez.org/cases/2000/00-949
# https://www.oyez.org/cases/1994/94-771
# https://www.oyez.org/cases/1999/99-5153
# https://www.oyez.org/cases/1991/91-453
# https://www.oyez.org/cases/1994/94-3
# https://www.oyez.org/cases/1999/98-791
# https://www.oyez.org/cases/1993/92-1441
# https://www.oyez.org/cases/1999/99-830
# https://www.oyez.org/cases/1993/92-1292
# https://www.oyez.org/cases/2001/00-1737
# https://www.oyez.org/cases/2000/99-1295
# https://www.oyez.org/cases/2000/00-5250
# https://www.oyez.org/cases/1998/97-1337
# https://www.oyez.org/cases/1999/98-1037
# https://www.oyez.org/cases/2002/01-1184
# https://www.oyez.org/cases/1997/97-215
# https://www.oyez.org/cases/1999/98-1667
# https://www.oyez.org/cases/1995/94-7427
# https://www.oyez.org/cases/1993/92-8556
# https://www.oyez.org/cases/1997/96-1769
# https://www.oyez.org/cases/2000/00-191
# https://www.oyez.org/cases/1995/95-5015
# https://www.oyez.org/cases/1999/99-224
# https://www.oyez.org/cases/1997/97-454
# https://www.oyez.org/cases/1996/96-454
# https://www.oyez.org/cases/1991/91-126
# https://www.oyez.org/cases/1991/91-372
# https://www.oyez.org/cases/1994/94-325
# https://www.oyez.org/cases/1995/94-1592
# https://www.oyez.org/cases/1995/95-124
# https://www.oyez.org/cases/1991/91-42
# https://www.oyez.org/cases/1995/94-896
# https://www.oyez.org/cases/1991/90-1262
# https://www.oyez.org/cases/1993/93-284
# https://www.oyez.org/cases/1997/96-7185
# https://www.oyez.org/cases/2001/01-631
# https://www.oyez.org/cases/1995/94-7448
# https://www.oyez.org/cases/1993/92-1384
# https://www.oyez.org/cases/1998/97-7164
# https://www.oyez.org/cases/1997/96-1133
# https://www.oyez.org/cases/2001/01-687
# https://www.oyez.org/cases/1999/98-1152
# https://www.oyez.org/cases/2001/00-6933
# https://www.oyez.org/cases/1991/90-918
# https://www.oyez.org/cases/1981/80-1690
# https://www.oyez.org/cases/1993/93-880
# https://www.oyez.org/cases/2000/99-1434
# https://www.oyez.org/cases/1991/90-711
# https://www.oyez.org/cases/1994/93-768
# https://www.oyez.org/cases/2001/00-1595
# https://www.oyez.org/cases/1995/95-365
# https://www.oyez.org/cases/1996/95-1455
# https://www.oyez.org/cases/1991/90-6352
# https://www.oyez.org/cases/1992/91-1496
# https://www.oyez.org/cases/2002/01-1243
# https://www.oyez.org/cases/1998/98-84
# https://www.oyez.org/cases/2000/00-596
# https://www.oyez.org/cases/1998/97-1625
# https://www.oyez.org/cases/1995/95-6
# https://www.oyez.org/cases/1992/91-1677
# https://www.oyez.org/cases/1994/93-1260
# https://www.oyez.org/cases/1995/95-591
# https://www.oyez.org/cases/2000/99-1132
# https://www.oyez.org/cases/1993/92-9093
# https://www.oyez.org/cases/1995/95-754
# https://www.oyez.org/cases/2000/99-1994
# https://www.oyez.org/cases/1997/96-1923
# https://www.oyez.org/cases/2002/01-1444
# https://www.oyez.org/cases/2001/01-463
# https://www.oyez.org/cases/1998/97-1704
# https://www.oyez.org/cases/1997/96-370
# https://www.oyez.org/cases/1994/94-23
# https://www.oyez.org/cases/1999/99-138
# https://www.oyez.org/cases/1992/91-1421
# https://www.oyez.org/cases/1999/99-166
# https://www.oyez.org/cases/1994/93-981
# https://www.oyez.org/cases/1995/94-9088
# https://www.oyez.org/cases/2002/01-1325
# https://www.oyez.org/cases/1998/98-10
# https://www.oyez.org/cases/1993/92-833
# https://www.oyez.org/cases/1994/94-514
# https://www.oyez.org/cases/2001/99-1786
# https://www.oyez.org/cases/1997/97-300
# https://www.oyez.org/cases/1992/91-2079
# https://www.oyez.org/cases/1993/92-1550
# https://www.oyez.org/cases/1993/92-1750
# https://www.oyez.org/cases/1992/91-10
# https://www.oyez.org/cases/1998/97-475
# https://www.oyez.org/cases/2000/00-276
# https://www.oyez.org/cases/2002/02-722
# https://www.oyez.org/cases/2001/01-344
# https://www.oyez.org/cases/1997/97-372
# https://www.oyez.org/cases/1991/90-7675
# https://www.oyez.org/cases/1998/98-591
# https://www.oyez.org/cases/2000/00-151
# https://www.oyez.org/cases/2002/01-1559
# https://www.oyez.org/cases/1997/96-1693
# https://www.oyez.org/cases/2000/99-7791
# https://www.oyez.org/cases/1993/93-5256
# https://www.oyez.org/cases/2000/00-203
# https://www.oyez.org/cases/1991/90-1745
# https://www.oyez.org/cases/1991/90-1802
# https://www.oyez.org/cases/1993/92-1168
# https://www.oyez.org/cases/2000/99-9136
# https://www.oyez.org/cases/1997/97-581
# https://www.oyez.org/cases/2000/00-391
# https://www.oyez.org/cases/1998/97-1868
# https://www.oyez.org/cases/2000/99-1864
# https://www.oyez.org/cases/1993/93-289
# https://www.oyez.org/cases/1991/90-1342
# https://www.oyez.org/cases/1997/96-1375
# https://www.oyez.org/cases/1998/98-208
# https://www.oyez.org/cases/1997/96-1590
# https://www.oyez.org/cases/2000/00-549
# https://www.oyez.org/cases/1997/97-569
# https://www.oyez.org/cases/2002/02-299
# https://www.oyez.org/cases/1999/98-1949
# https://www.oyez.org/cases/1996/95-1201
# https://www.oyez.org/cases/2001/00-1614
# https://www.oyez.org/cases/1991/90-1126
# https://www.oyez.org/cases/1994/93-1525
# https://www.oyez.org/cases/1995/94-1614
# https://www.oyez.org/cases/1997/97-29
# https://www.oyez.org/cases/1998/98-727
# https://www.oyez.org/cases/1992/92-94
# https://www.oyez.org/cases/2000/99-1848
# https://www.oyez.org/cases/1996/95-6556
# https://www.oyez.org/cases/1995/94-1785
# https://www.oyez.org/cases/1996/95-1268
# https://www.oyez.org/cases/1996/95-1376
# https://www.oyez.org/cases/1996/95-1598
# https://www.oyez.org/cases/1994/94-6790
# https://www.oyez.org/cases/1991/91-5118
# https://www.oyez.org/cases/1994/93-1408
# https://www.oyez.org/cases/2001/00-9285
# https://www.oyez.org/cases/1992/91-998
# https://www.oyez.org/cases/2001/00-730
# https://www.oyez.org/cases/1991/90-1629
# https://www.oyez.org/cases/1992/91-6194
# https://www.oyez.org/cases/1991/90-1972
# https://www.oyez.org/cases/1994/93-7659
# https://www.oyez.org/cases/2002/01-1375
# https://www.oyez.org/cases/2000/99-1613
# https://www.oyez.org/cases/1999/98-2060
# https://www.oyez.org/cases/1996/95-813
# https://www.oyez.org/cases/1992/92-725
# https://www.oyez.org/cases/1998/98-830
# https://www.oyez.org/cases/1992/91-7358
# https://www.oyez.org/cases/1991/91-155
# https://www.oyez.org/cases/2000/00-5961
# https://www.oyez.org/cases/1993/93-518
# https://www.oyez.org/cases/2000/99-6218
# https://www.oyez.org/cases/1998/97-1056
# https://www.oyez.org/cases/1998/97-1754
# https://www.oyez.org/cases/1993/92-757
# https://www.oyez.org/cases/1998/97-1927
# https://www.oyez.org/cases/1994/93-1504
# https://www.oyez.org/cases/1993/93-5770
# https://www.oyez.org/cases/1991/90-1014
# https://www.oyez.org/cases/1996/95-1352
# https://www.oyez.org/cases/1997/96-1569
# https://www.oyez.org/cases/1995/95-719
# https://www.oyez.org/cases/1999/98-678
# https://www.oyez.org/cases/1996/95-2024
# https://www.oyez.org/cases/2002/01-1269
# https://www.oyez.org/cases/1992/91-8685
# https://www.oyez.org/cases/2002/01-593
# https://www.oyez.org/cases/1996/95-1726
# https://www.oyez.org/cases/1991/91-119
# https://www.oyez.org/cases/1993/93-263
# https://www.oyez.org/cases/1999/98-9828
# https://www.oyez.org/cases/2001/00-878
# https://www.oyez.org/cases/1991/91-194
# https://www.oyez.org/cases/2000/00-152
# https://www.oyez.org/cases/2002/01-188
# https://www.oyez.org/cases/1999/98-1480
# https://www.oyez.org/cases/1995/95-173
# https://www.oyez.org/cases/1995/94-1966
# https://www.oyez.org/cases/1994/93-1636
# https://www.oyez.org/cases/1992/91-2051
# https://www.oyez.org/cases/1992/91-6516
# https://www.oyez.org/cases/1993/93-6188
# https://www.oyez.org/cases/1992/92-621
# https://www.oyez.org/cases/1997/97-461
# https://www.oyez.org/cases/1991/90-1124
# https://www.oyez.org/cases/1994/94-749
# https://www.oyez.org/cases/1998/98-377
# https://www.oyez.org/cases/2000/00-763
# https://www.oyez.org/cases/1991/91-72
# https://www.oyez.org/cases/1998/98-436
# https://www.oyez.org/cases/1996/95-1595
# https://www.oyez.org/cases/2001/00-568
# https://www.oyez.org/cases/1996/96-491
# https://www.oyez.org/cases/1992/92-351
# https://www.oyez.org/cases/1995/95-6510
# https://www.oyez.org/cases/2001/00-1293
# https://www.oyez.org/cases/1998/98-531
# https://www.oyez.org/cases/2000/99-1240
# https://www.oyez.org/cases/1991/90-1419
# https://www.oyez.org/cases/2000/00-201
# https://www.oyez.org/cases/1997/96-1469
# https://www.oyez.org/cases/1998/98-347
# https://www.oyez.org/cases/2000/99-1030
# https://www.oyez.org/cases/1994/94-590
# https://www.oyez.org/cases/2000/99-1702
# https://www.oyez.org/cases/1994/94-367
# https://www.oyez.org/cases/1993/93-377
# https://www.oyez.org/cases/1992/92-603
# https://www.oyez.org/cases/2001/01-408
# https://www.oyez.org/cases/1999/98-1696
# https://www.oyez.org/cases/1968/21
# https://www.oyez.org/cases/2001/00-973
# https://www.oyez.org/cases/1997/96-188
# https://www.oyez.org/cases/1999/98-1161
# https://www.oyez.org/cases/1991/90-5844
# https://www.oyez.org/cases/1993/92-519
# https://www.oyez.org/cases/1992/91-1200
# https://www.oyez.org/cases/2002/02-337
# https://www.oyez.org/cases/1997/96-7151
# https://www.oyez.org/cases/1996/95-853
# https://www.oyez.org/cases/2000/99-929
# https://www.oyez.org/cases/2000/00-292
# https://www.oyez.org/cases/1996/94-1474
# https://www.oyez.org/cases/1995/94-1837
# https://www.oyez.org/cases/1993/92-8894
# https://www.oyez.org/cases/1992/91-790
# https://www.oyez.org/cases/1994/94-329
# https://www.oyez.org/cases/1999/99-387
# https://www.oyez.org/cases/2002/01-706
# https://www.oyez.org/cases/2001/01-419
# https://www.oyez.org/cases/1992/92-551
# https://www.oyez.org/cases/1999/98-1991
# https://www.oyez.org/cases/1991/90-1604
# https://www.oyez.org/cases/1992/92-311
# https://www.oyez.org/cases/1992/91-1600
# https://www.oyez.org/cases/1997/96-1370
# https://www.oyez.org/cases/1984/83-1035
# https://www.oyez.org/cases/1992/92-6033
# https://www.oyez.org/cases/1998/96-1793
# https://www.oyez.org/cases/1992/91-1526
# https://www.oyez.org/cases/1991/90-848
# https://www.oyez.org/cases/1999/98-1170
# https://www.oyez.org/cases/2000/00-347
# https://www.oyez.org/cases/2000/99-1257
# https://www.oyez.org/cases/1993/93-356
# https://www.oyez.org/cases/2002/02-271
# https://www.oyez.org/cases/1991/90-8466
# https://www.oyez.org/cases/1992/92-190
# https://www.oyez.org/cases/2002/01-7574
# https://www.oyez.org/cases/2002/01-950
# https://www.oyez.org/cases/1997/97-634
# https://www.oyez.org/cases/1994/94-226
# https://www.oyez.org/cases/1998/97-1489
# https://www.oyez.org/cases/1998/97-1235
# https://www.oyez.org/cases/2000/99-1408
# https://www.oyez.org/cases/1994/94-197
# https://www.oyez.org/cases/1999/98-1701
# https://www.oyez.org/cases/1999/99-502
# https://www.oyez.org/cases/1998/97-1418
# https://www.oyez.org/cases/2002/02-311
# https://www.oyez.org/cases/2001/00-799
# https://www.oyez.org/cases/1994/93-1199
# https://www.oyez.org/cases/1997/97-391
# https://www.oyez.org/cases/2002/02-524
# https://www.oyez.org/cases/1992/91-1513
# https://www.oyez.org/cases/2002/01-1435
# https://www.oyez.org/cases/1996/96-667
# https://www.oyez.org/cases/2002/02-403
# https://www.oyez.org/cases/1967/67
# https://www.oyez.org/cases/2001/00-1543
# https://www.oyez.org/cases/1995/94-12
# https://www.oyez.org/cases/1996/95-7452
# https://www.oyez.org/cases/1987/85-673
# https://www.oyez.org/cases/1997/96-1060
# https://www.oyez.org/cases/1998/96-1570
# https://www.oyez.org/cases/2001/00-1307
# https://www.oyez.org/cases/2000/99-1331
# https://www.oyez.org/cases/1999/98-896
# https://www.oyez.org/cases/1998/97-53
# https://www.oyez.org/cases/1996/95-966
# https://www.oyez.org/cases/1999/98-1189
# https://www.oyez.org/cases/1992/91-1671
# https://www.oyez.org/cases/1993/92-1956
# https://www.oyez.org/cases/1994/93-1151
# https://www.oyez.org/cases/1993/93-5418
# https://www.oyez.org/cases/2002/02-516
# https://www.oyez.org/cases/1996/96-6298
# https://www.oyez.org/cases/1995/95-191
# https://www.oyez.org/cases/1996/96-320
# https://www.oyez.org/cases/1994/94-820
# https://www.oyez.org/cases/2000/99-1792
# https://www.oyez.org/cases/1998/97-2044
# https://www.oyez.org/cases/1956/21
# https://www.oyez.org/cases/2002/02-94
# https://www.oyez.org/cases/1994/92-2038
# https://www.oyez.org/cases/1991/91-636
# https://www.oyez.org/cases/1992/91-1188
# https://www.oyez.org/cases/1992/91-1958
# https://www.oyez.org/cases/1994/94-631
# https://www.oyez.org/cases/2000/99-603
# https://www.oyez.org/cases/2002/02-196
# https://www.oyez.org/cases/1995/94-1239
# https://www.oyez.org/cases/1993/93-144
# https://www.oyez.org/cases/2001/01-400
# https://www.oyez.org/cases/1993/92-1482
# https://www.oyez.org/cases/1998/97-303
# https://www.oyez.org/cases/1998/97-1396
# https://www.oyez.org/cases/2001/00-1167
# https://www.oyez.org/cases/1993/92-896
# https://www.oyez.org/cases/2000/99-2047
# https://www.oyez.org/cases/1993/92-7247
# https://www.oyez.org/cases/2001/01-46
# https://www.oyez.org/cases/1994/93-1001
# https://www.oyez.org/cases/1995/94-1654
# https://www.oyez.org/cases/1997/96-8400
# https://www.oyez.org/cases/2001/00-6567
# https://www.oyez.org/cases/1986/85-1199
# https://www.oyez.org/cases/1991/90-6861
# https://www.oyez.org/cases/2002/02-361

# %%
len(unique_urls)
# Out:
# 990

# %%
def convert_dataset_to_dataframe(dataset):
    data_opinion = []
    for item in dataset['train']:
        data_opinion.append({
            'id': item['id'],
            'year': item['year'],
            'url': item['url'],
            'opinionOfTheCourt': item['opinionOfTheCourt'],
            'syllabus': item['syllabus'],
            'issueArea': item['issueArea'],
            'decisionDirection': item['decisionDirection']
        })
    
    df = pd.DataFrame(data_opinion)
    return df

# %%
from sklearn.model_selection import StratifiedShuffleSplit
from datasets import Dataset
from transformers import LEDTokenizer, LEDForConditionalGeneration, Seq2SeqTrainingArguments, Trainer

df = convert_dataset_to_dataframe(dataset2)


# Create a combined stratification column
df['stratify_col'] = df['issueArea'].astype(str) + '_' + df['decisionDirection'].astype(str)

# Filter out classes with fewer than 2 samples
class_counts = df['stratify_col'].value_counts()
valid_classes = class_counts[class_counts >= 2].index
df = df[df['stratify_col'].isin(valid_classes)]

# Initialize StratifiedShuffleSplit
split = StratifiedShuffleSplit(n_splits=1, test_size=0.25, random_state=42)
for train_index, temp_index in split.split(df, df['stratify_col']):
    train_df = df.iloc[train_index]
    temp_df = df.iloc[temp_index]

# Filter out classes with fewer than 2 samples in the temporary dataset
temp_class_counts = temp_df['stratify_col'].value_counts()
valid_temp_classes = temp_class_counts[temp_class_counts >= 2].index
temp_df = temp_df[temp_df['stratify_col'].isin(valid_temp_classes)]

# Further split the temp_df into validation and test sets
split = StratifiedShuffleSplit(n_splits=1, test_size=0.6, random_state=42)
for val_index, test_index in split.split(temp_df, temp_df['stratify_col']):
    val_df = temp_df.iloc[val_index]
    test_df = temp_df.iloc[test_index]

# Drop the stratification column
train_df = train_df.drop(columns=['stratify_col'])
val_df = val_df.drop(columns=['stratify_col'])
test_df = test_df.drop(columns=['stratify_col'])

# Convert to Hugging Face Datasets
train_dataset = Dataset.from_pandas(train_df)
val_dataset = Dataset.from_pandas(val_df)
test_dataset = Dataset.from_pandas(test_df)

# Print the distribution to verify
print("Training set distribution:")
print(train_df['issueArea'].value_counts(normalize=True))
print(train_df['decisionDirection'].value_counts(normalize=True))

print("\nValidation set distribution:")
print(val_df['issueArea'].value_counts(normalize=True))
print(val_df['decisionDirection'].value_counts(normalize=True))

print("\nTest set distribution:")
print(test_df['issueArea'].value_counts(normalize=True))
print(test_df['decisionDirection'].value_counts(normalize=True))
# Out:
# Training set distribution:
# issueArea
# 1.0     0.218613
# 8.0     0.202374
# 2.0     0.172392
# 9.0     0.105559
# 3.0     0.093691
# 7.0     0.056527
# 4.0     0.043410
# 12.0    0.042161
# 10.0    0.040912
# 6.0     0.012180
# 5.0     0.012180
# Name: proportion, dtype: float64
# decisionDirection
# 2.0    0.533729
# 1.0    0.466271
# Name: proportion, dtype: float64
#
# Validation set distribution:
# issueArea
# 1.0     0.217799
# 8.0     0.201405
# 2.0     0.170960
# 9.0     0.105386
# 3.0     0.093677
# 7.0     0.056206
# 4.0     0.044496
# 10.0    0.042155
# 12.0    0.042155
# 5.0     0.014052
# 6.0     0.011710
# Name: proportion, dtype: float64
# decisionDirection
# 2.0    0.533958
# 1.0    0.466042
# Name: proportion, dtype: float64
#
# Test set distribution:
# issueArea
# 1.0     0.219969
# 8.0     0.202808
# 2.0     0.173167
# 9.0     0.106084
# 3.0     0.092044
# 7.0     0.057722
# 12.0    0.042122
# 4.0     0.042122
# 10.0    0.040562
# 6.0     0.012480
# 5.0     0.010920
# Name: proportion, dtype: float64
# decisionDirection
# 2.0    0.536661
# 1.0    0.463339
# Name: proportion, dtype: float64

# %%
# !df -h
# !du -sh
# !ls -la
# Out:
# Filesystem              Size  Used Avail Use% Mounted on
# tmpfs                    26G   13M   26G   1% /run
# /dev/mapper/local-root  147G   56G   84G  41% /
# tmpfs                   126G   39M  126G   1% /dev/shm
# tmpfs                   5.0M  4.0K  5.0M   1% /run/lock
# /dev/nvme0n1p1          1.1G  6.1M  1.1G   1% /boot/efi
# /dev/mapper/local-home  731G  687G  6.6G 100% /home
# /dev/sda1                13T  8.6T  3.5T  72% /srv
# tmpfs                    26G  8.0K   26G   1% /run/user/1070
# tmpfs                    26G  8.0K   26G   1% /run/user/1023
# tmpfs                    26G  8.0K   26G   1% /run/user/1075
# tmpfs                    26G  8.0K   26G   1% /run/user/1055
# tmpfs                    26G  8.0K   26G   1% /run/user/1076
# tmpfs                    26G  8.0K   26G   1% /run/user/1019
# tmpfs                    26G  8.0K   26G   1% /run/user/1004
# tmpfs                    26G  8.0K   26G   1% /run/user/1057
# tmpfs                    26G  8.0K   26G   1% /run/user/1074
# 1.3G	.
# total 1006384
# drwxrwxr-x 4 mostah mostah       4096 Oct  6 17:53  .
# drwxrwxr-x 3 mostah mostah       4096 May 31 00:59  ..
# -rw-rw-r-- 1 mostah mostah 1029975381 May 31 00:40  case_with_all_sources_with_companion_cases_tag.jsonl
# -rw-rw-r-- 1 mostah mostah     207742 Oct  6 17:52  data_preparation.ipynb
# drwxrwxr-x 8 mostah mostah       4096 Oct  5 14:19  .git
# -rw-rw-r-- 1 mostah mostah         53 Oct  5 14:16  .gitignore
# -rw-rw-r-- 1 mostah mostah      10178 Oct  6 16:13  oldCode.py
# drwxrwxr-x 2 mostah mostah       4096 Oct  6 16:41  results
# -rw-rw-r-- 1 mostah mostah     207742 Oct  6 17:53 'SS-LED copy.ipynb'
# -rw-rw-r-- 1 mostah mostah     103097 Oct  6 17:54  SS-LED.ipynb

# %%
# Load the tokenizer
tokenizer = LEDTokenizer.from_pretrained('allenai/led-base-16384')
i=0
def preprocess_function(examples):
    print(len(examples))
    inputs = examples['opinionOfTheCourt']
    targets = examples['syllabus']
    model_inputs = tokenizer(inputs, max_length=16000, truncation=True, padding='max_length')
    labels = tokenizer(targets, max_length=1000, truncation=True, padding='max_length')

    print(i+1)

    model_inputs['labels'] = labels['input_ids']

    batch = {}
    batch["input_ids"] = model_inputs.input_ids
    batch["attention_mask"] = model_inputs.attention_mask

    # create 0 global_attention_mask lists
    batch["global_attention_mask"] = len(batch["input_ids"]) * [
        [0 for _ in range(len(batch["input_ids"][0]))]
    ]

    # since above lists are references, the following line changes the 0 index for all samples
    batch["global_attention_mask"][0][0] = 1
    batch["labels"] = labels.input_ids

    # We have to make sure that the PAD token is ignored
    # -100 for loss
    batch["labels"] = [
        [-100 if token == tokenizer.pad_token_id else token for token in labels]
        for labels in batch["labels"]
    ]

    return batch

# Apply the preprocessing function to the datasets
tokenized_train_dataset = train_dataset.map(preprocess_function, batched=True, remove_columns=train_dataset.column_names)
tokenized_val_dataset = val_dataset.map(preprocess_function, batched=True, remove_columns=val_dataset.column_names)
tokenized_test_dataset = test_dataset.map(preprocess_function, batched=True, remove_columns=test_dataset.column_names)
# Out:
# Map:   0%|          | 0/3202 [00:00<?, ? examples/s]
# 8
# 1
# Map:  31%|███       | 1000/3202 [00:18<00:41, 53.10 examples/s]
# 8
# 1
# Map:  62%|██████▏   | 2000/3202 [00:36<00:21, 54.84 examples/s]
# 8
# Map:  62%|██████▏   | 2000/3202 [00:48<00:21, 54.84 examples/s]
# 1
# Map:  94%|█████████▎| 3000/3202 [00:55<00:03, 54.34 examples/s]
# 8
# 1
# Map: 100%|██████████| 3202/3202 [00:58<00:00, 54.50 examples/s]
# Map:   0%|          | 0/427 [00:00<?, ? examples/s]
# 8
# 1
# Map: 100%|██████████| 427/427 [00:08<00:00, 52.76 examples/s]
# Map:   0%|          | 0/641 [00:00<?, ? examples/s]
# 8
# 1
# Map: 100%|██████████| 641/641 [00:11<00:00, 55.61 examples/s]

# %%
import torch

# Set the device to GPU 2
device = torch.device("cuda:2" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda:2

# %%
# Load the model
model = LEDForConditionalGeneration.from_pretrained('allenai/led-base-16384')

# Set generate hyperparameters
model.config.num_beams = 2
model.config.max_length = 16000
model.config.min_length = 1000
model.config.length_penalty = 2.0
model.config.early_stopping = True
model.config.no_repeat_ngram_size = 3

# Define training arguments
training_args = Seq2SeqTrainingArguments(
    output_dir='./results',
    evaluation_strategy='epoch',
    learning_rate=2e-5,
    per_device_train_batch_size=2,
    per_device_eval_batch_size=2,
    num_train_epochs=3,
    weight_decay=0.01,
    save_total_limit=2,
    predict_with_generate=True,
    fp16=True,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_train_dataset,
    eval_dataset=tokenized_val_dataset,
)

# Train the model
trainer.train()

# Evaluate the model
results = trainer.evaluate()
print("Evaluation results:", results)

# Generate summaries
def generate_summary(opinion):
    inputs = tokenizer(opinion, return_tensors='pt', max_length=16383, truncation=True, padding='max_length')
    summary_ids = model.generate(inputs['input_ids'].to("cuda"), max_length=1000, num_beams=4, early_stopping=True)
    return tokenizer.decode(summary_ids[0], skip_special_tokens=True)

# Test the model on a sample opinion
sample_opinion = df['opinionOfTheCourt'].iloc[0]
print("Opinion:", sample_opinion)
print("Generated Summary:", generate_summary(sample_opinion))
# Out:
# /home/mostah/anaconda3/envs/myenv/lib/python3.11/site-packages/transformers/training_args.py:1474: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Input ids are automatically padded from 16000 to 16384 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 16000 to 16384 to be a multiple of `config.attention_window`: 1024
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[37], line 34
#      26 trainer = Trainer(
#      27     model=model,
#      28     args=training_args,
#      29     train_dataset=tokenized_train_dataset,
#      30     eval_dataset=tokenized_val_dataset,
#      31 )
#      33 # Train the model
# ---> 34 trainer.train()
#      36 # Evaluate the model
#      37 results = trainer.evaluate()
#
# File ~/anaconda3/envs/myenv/lib/python3.11/site-packages/transformers/trainer.py:1885, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1883         hf_hub_utils.enable_progress_bars()
#    1884 else:
# -> 1885     return inner_training_loop(
#    1886         args=args,
#    1887         resume_from_checkpoint=resume_from_checkpoint,
#    1888         trial=trial,
#    1889         ignore_keys_for_eval=ignore_keys_for_eval,
#    1890     )
#
# File ~/anaconda3/envs/myenv/lib/python3.11/site-packages/transformers/trainer.py:2216, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2213     self.control = self.callback_handler.on_step_begin(args, self.state, self.control)
#    2215 with self.accelerator.accumulate(model):
# -> 2216     tr_loss_step = self.training_step(model, inputs)
#    2218 if (
#    2219     args.logging_nan_inf_filter
#    2220     and not is_torch_xla_available()
#    2221     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    2222 ):
#    2223     # if loss is nan or inf simply add the average of previous logged losses
#    2224     tr_loss += tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File ~/anaconda3/envs/myenv/lib/python3.11/site-packages/transformers/trainer.py:3238, in Trainer.training_step(self, model, inputs)
#    3235     return loss_mb.reduce_mean().detach().to(self.args.device)
#    3237 with self.compute_loss_context_manager():
# -> 3238     loss = self.compute_loss(model, inputs)
#    3240 del inputs
#    3241 torch.cuda.empty_cache()
#
# File ~/anaconda3/envs/myenv/lib/python3.11/site-packages/transformers/trainer.py:3264, in Trainer.compute_loss(self, model, inputs, return_outputs)
#    3262 else:
#    3263     labels = None
# -> 3264 outputs = model(**inputs)
#    3265 # Save past state if it exists
#    3266 # TODO: this needs to be fixed and made cleaner later.
#    3267 if self.args.past_index >= 0:
#
# File ~/anaconda3/envs/myenv/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/myenv/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/anaconda3/envs/myenv/lib/python3.11/site-packages/torch/nn/parallel/data_parallel.py:185, in DataParallel.forward(self, *inputs, **kwargs)
#     183     return self.module(*inputs[0], **module_kwargs[0])
#     184 replicas = self.replicate(self.module, self.device_ids[:len(inputs)])
# --> 185 outputs = self.parallel_apply(replicas, inputs, module_kwargs)
#     186 return self.gather(outputs, self.output_device)
#
# File ~/anaconda3/envs/myenv/lib/python3.11/site-packages/torch/nn/parallel/data_parallel.py:200, in DataParallel.parallel_apply(self, replicas, inputs, kwargs)
#     199 def parallel_apply(self, replicas: Sequence[T], inputs: Sequence[Any], kwargs: Any) -> List[Any]:
# --> 200     return parallel_apply(replicas, inputs, kwargs, self.device_ids[:len(replicas)])
#
# File ~/anaconda3/envs/myenv/lib/python3.11/site-packages/torch/nn/parallel/parallel_apply.py:108, in parallel_apply(modules, inputs, kwargs_tup, devices)
#     106     output = results[i]
#     107     if isinstance(output, ExceptionWrapper):
# --> 108         output.reraise()
#     109     outputs.append(output)
#     110 return outputs
#
# File ~/anaconda3/envs/myenv/lib/python3.11/site-packages/torch/_utils.py:705, in ExceptionWrapper.reraise(self)
#     701 except TypeError:
#     702     # If the exception takes multiple arguments, don't try to
#     703     # instantiate since we don't know how to
#     704     raise RuntimeError(msg) from None
# --> 705 raise exception
#
# OutOfMemoryError: Caught OutOfMemoryError in replica 0 on device 0.
# Original Traceback (most recent call last):
#   File "/home/mostah/anaconda3/envs/myenv/lib/python3.11/site-packages/torch/nn/parallel/parallel_apply.py", line 83, in _worker
#     output = module(*input, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mostah/anaconda3/envs/myenv/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mostah/anaconda3/envs/myenv/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mostah/anaconda3/envs/myenv/lib/python3.11/site-packages/transformers/models/led/modeling_led.py", line 2398, in forward
#     outputs = self.led(
#               ^^^^^^^^^
#   File "/home/mostah/anaconda3/envs/myenv/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mostah/anaconda3/envs/myenv/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mostah/anaconda3/envs/myenv/lib/python3.11/site-packages/transformers/models/led/modeling_led.py", line 2248, in forward
#     encoder_outputs = self.encoder(
#                       ^^^^^^^^^^^^^
#   File "/home/mostah/anaconda3/envs/myenv/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mostah/anaconda3/envs/myenv/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mostah/anaconda3/envs/myenv/lib/python3.11/site-packages/transformers/models/led/modeling_led.py", line 1866, in forward
#     layer_outputs = encoder_layer(
#                     ^^^^^^^^^^^^^^
#   File "/home/mostah/anaconda3/envs/myenv/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mostah/anaconda3/envs/myenv/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mostah/anaconda3/envs/myenv/lib/python3.11/site-packages/transformers/models/led/modeling_led.py", line 952, in forward
#     attn_outputs = self.self_attn(
#                    ^^^^^^^^^^^^^^^
#   File "/home/mostah/anaconda3/envs/myenv/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mostah/anaconda3/envs/myenv/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mostah/anaconda3/envs/myenv/lib/python3.11/site-packages/transformers/models/led/modeling_led.py", line 761, in forward
#     self_outputs = self.longformer_self_attn(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mostah/anaconda3/envs/myenv/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mostah/anaconda3/envs/myenv/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mostah/anaconda3/envs/myenv/lib/python3.11/site-packages/transformers/models/led/modeling_led.py", line 248, in forward
#     attn_probs = torch.masked_fill(attn_probs, is_index_masked[:, :, None, None], 0.0)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# torch.cuda.OutOfMemoryError: CUDA out of memory. Tried to allocate 1.50 GiB. GPU
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df['generated_summary'] = df['opinionOfTheCourt'].apply(generate_summary)

# Prepare data for BERT
bert_tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

def preprocess_bert_function(examples):
    return bert_tokenizer(examples['generated_summary'], padding='max_length', truncation=True, max_length=512)

# Convert the DataFrame to a Dataset
bert_dataset = Dataset.from_pandas(df)

# Apply the preprocessing function to the dataset
tokenized_bert_dataset = bert_dataset.map(preprocess_bert_function, batched=True)

# Split the dataset into train, validation, and test sets
split = StratifiedShuffleSplit(n_splits=1, test_size=0.3, random_state=42)
for train_index, temp_index in split.split(df, df['stratify_col']):
    train_df = df.iloc[train_index]
    temp_df = df.iloc[temp_index]

split = StratifiedShuffleSplit(n_splits=1, test_size=0.5, random_state=42)
for val_index, test_index in split.split(temp_df, temp_df['stratify_col']):
    val_df = temp_df.iloc[val_index]
    test_df = temp_df.iloc[test_index]

# Convert to Hugging Face Datasets
train_dataset = Dataset.from_pandas(train_df)
val_dataset = Dataset.from_pandas(val_df)
test_dataset = Dataset.from_pandas(test_df)

# %%
# Load the BERT model
bert_model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=2)

# Define training arguments for BERT
bert_training_args = TrainingArguments(
    output_dir='./bert_results',
    evaluation_strategy='epoch',
    learning_rate=2e-5,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=3,
    weight_decay=0.01,
    logging_dir='./logs',
    logging_steps=10,
)

# Initialize the Trainer for BERT
bert_trainer = Trainer(
    model=bert_model,
    args=bert_training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
)

# Train the BERT model
bert_trainer.train()

# Evaluate the BERT model
bert_results = bert_trainer.evaluate()
print("BERT Evaluation results:", bert_results)

# %%
# Predict decisionDirection using BERT
predictions = bert_trainer.predict(test_dataset)
predicted_labels = np.argmax(predictions.predictions, axis=1)

# Calculate the decision direction flip rate
original_labels = test_df['decisionDirection'].values
flip_rate = np.mean(predicted_labels != original_labels)
print("Decision Direction Flip Rate:", flip_rate)

# Calculate the distance-based metric
probabilities = torch.nn.functional.softmax(torch.tensor(predictions.predictions), dim=-1).numpy()
original_probabilities = np.zeros_like(probabilities)
for i, label in enumerate(original_labels):
    original_probabilities[i, label] = 1

absolute_differences = np.abs(probabilities - original_probabilities)
distance_metric = np.mean(np.sum(absolute_differences, axis=1))
print("Distance-based Metric:", distance_metric)

# %%
# Assuming you have already trained the BERT model and have the test dataset

# Predict decisionDirection using BERT
predictions = bert_trainer.predict(test_dataset)
predicted_labels = np.argmax(predictions.predictions, axis=1)

# Extract original labels and group information
original_labels = test_df['decisionDirection'].values
issue_areas = test_df['issueArea'].values

# Define groups based on issueArea
groups = np.unique(issue_areas)

# Initialize dictionaries to store metrics
accuracy = {}
precision = {}
recall = {}
f1 = {}

# Calculate metrics for each group
for group in groups:
    group_indices = np.where(issue_areas == group)[0]
    group_original_labels = original_labels[group_indices]
    group_predicted_labels = predicted_labels[group_indices]
    
    accuracy[group] = accuracy_score(group_original_labels, group_predicted_labels)
    precision[group] = precision_score(group_original_labels, group_predicted_labels, average='macro')
    recall[group] = recall_score(group_original_labels, group_predicted_labels, average='macro')
    f1[group] = f1_score(group_original_labels, group_predicted_labels, average='macro')

# Print metrics for each group
for group in groups:
    print(f"Issue Area {group}:")
    print(f"  Accuracy: {accuracy[group]:.4f}")
    print(f"  Precision: {precision[group]:.4f}")
    print(f"  Recall: {recall[group]:.4f}")
    print(f"  F1 Score: {f1[group]:.4f}")

# Apply the 80% Rule
selection_rates = {group: np.mean(predicted_labels[issue_areas == group] == 1) for group in groups}
max_selection_rate = max(selection_rates.values())
for group, rate in selection_rates.items():
    if rate < 0.8 * max_selection_rate:
        print(f"Group {group} violates the 80% rule with a selection rate of {rate:.4f}")

# Calculate Statistical Parity
positive_rates = {group: np.mean(predicted_labels[issue_areas == group] == 1) for group in groups}
for group, rate in positive_rates.items():
    print(f"Group {group} positive prediction rate: {rate:.4f}")

# Calculate Equalized Odds
true_positive_rates = {group: np.mean((predicted_labels[issue_areas == group] == 1) & (original_labels[issue_areas == group] == 1)) for group in groups}
false_positive_rates = {group: np.mean((predicted_labels[issue_areas == group] == 1) & (original_labels[issue_areas == group] == 0)) for group in groups}
for group in groups:
    print(f"Group {group} true positive rate: {true_positive_rates[group]:.4f}")
    print(f"Group {group} false positive rate: {false_positive_rates[group]:.4f}")

# Visualize Disparities
fig, ax = plt.subplots(1, 3, figsize=(18, 6))
ax[0].bar(groups, [accuracy[group] for group in groups])
ax[0].set_title('Accuracy by Issue Area')
ax[0].set_xlabel('Issue Area')
ax[0].set_ylabel('Accuracy')

ax[1].bar(groups, [precision[group] for group in groups])
ax[1].set_title('Precision by Issue Area')
ax[1].set_xlabel('Issue Area')
ax[1].set_ylabel('Precision')

ax[2].bar(groups, [recall[group] for group in groups])
ax[2].set_title('Recall by Issue Area')
ax[2].set_xlabel('Issue Area')
ax[2].set_ylabel('Recall')

plt.show()
